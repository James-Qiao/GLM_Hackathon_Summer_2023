# %% [markdown]
# <a href="https://colab.research.google.com/github/pachterlab/BP_2020_2/blob/master/notebooks/log1p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !date
# Out:
# Sat Jul  8 15:17:47 HKT 2023

# %% [markdown]
# # Install software

# %%
# !pip install anndata
# Out:
# ...
# WARNING: You are using pip version 23.0.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/qiaojiamu/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# # Download data

# %%
# !git clone https://github.com/pachterlab/BP_2020_2.git
# Out:
# 正克隆到 'BP_2020_2'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 60 (delta 1), reused 0 (delta 0), pack-reused 52
# 接收对象中: 100% (60/60), 58.04 MiB | 5.95 MiB/s, 完成.
# 处理 delta 中: 100% (16/16), 完成.
# 正在更新文件: 100% (17/17), 完成.

# %%
# !cat BP_2020_2/data/raw/top BP_2020_2/data/raw/bot > BP_2020_2/data/raw/mtx
# !cat BP_2020_2/data/norm/top BP_2020_2/data/norm/bot > BP_2020_2/data/norm/mtx

# %% [markdown]
# # Log1p

# %%
import pandas as pd
import numpy as np
import anndata

from sklearn.preprocessing import normalize, scale
from collections import OrderedDict

from scipy.io import mmread
from scipy.sparse import csr_matrix
from scipy import stats

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


def nd(arr):
    return np.asarray(arr).reshape(-1)

def yex(ax):
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]
    
    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax


age_map = {
    "SRR8426358": 24,
    "SRR8426359": 24,
    "SRR8426362": 24,
    "SRR8426363": 24,
    "SRR8426364": 24,
    "SRR8426369": 24,
    "SRR8426370": 24,
    "SRR8426360": 3,
    "SRR8426361": 3,
    "SRR8426365": 3,
    "SRR8426366": 3,
    "SRR8426367": 3,
    "SRR8426368": 3,
    "SRR8426371": 3,
    "SRR8426372": 3
}

fsize=20

plt.rcParams.update({'font.size': fsize})

import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Load matrix

# %%
ace2_gene = "ENSMUSG00000015405"

# %%
bp = "BP_2020_2/data/"
obs = pd.read_csv(bp + "raw/E-CURD-9.aggregated_filtered_counts.mtx_cols", sep="\t", header=None, names=["SRR_bcs"])
var = pd.read_csv(bp + "raw/E-CURD-9.aggregated_filtered_counts.mtx_rows", sep="\t", header=None, names=["gene", "gene2"])
md  = pd.read_csv(bp + "metadata.txt", sep="\t")
del var["gene2"]
mtx = csr_matrix(mmread(bp+"raw/mtx").T)

md["age"] = md["Factor Value[age]"].str.split(" ").apply(lambda x: x[0])
md.index = md["Assay"].values

obs["SRR"] = obs.SRR_bcs.str.split("-").apply(lambda x: x[0])
obs["bcs"] = obs.SRR_bcs.str.split("-").apply(lambda x: x[1])
obs["age"] = obs.SRR.map(age_map)
obs["age"] = obs.SRR_bcs.map(md["age"])

# %%
adata = anndata.AnnData(X=mtx, obs=obs, var=var)
adata = adata[adata.obs.dropna(subset=["age"]).index] # There are 298 cells that are not in the "age_map", with only 1 cell expressing Ace2. We drop it.
adata.obs["age"] = adata.obs.age.astype(int)
# Out:
# /Users/qiaojiamu/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /var/folders/ms/kqznsr6n6934_wtng0twy8dw0000gn/T/ipykernel_63190/2978727684.py:3: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs["age"] = adata.obs.age.astype(int)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 11887 × 19632
#     obs: 'SRR_bcs', 'SRR', 'bcs', 'age'
#     var: 'gene'

# %% [markdown]
# # Process matrix

# %%
adata.layers["raw"] = adata.X
scale_num = 1000000
adata.layers["norm"] = normalize(adata.X, norm="l1", axis=1)*scale_num
adata.layers["log1p"] = np.log1p(adata.layers["raw"])
adata.uns = OrderedDict([("log1p", {"base":None})])
adata.layers["scale"] = scale(adata.layers["log1p"].todense(), axis=0, with_mean=True, with_std=True, copy=True)
# adata.X = adata.layers["scale"]
# Out:
# /Users/qiaojiamu/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 11887 × 19632
#     obs: 'SRR_bcs', 'SRR', 'bcs', 'age'
#     var: 'gene'
#     uns: 'log1p'
#     layers: 'raw', 'norm', 'log1p', 'scale'

# %%
ace2 = adata[:, np.where(adata.var["gene"]==ace2_gene)[0][0]]

# %%
df = ace2.obs.copy()
df["cnt"] = nd(ace2.layers["raw"].todense())
df["age"] = df.age.values.astype(int)

# %%
df.head()
# Out:
#                    SRR_bcs         SRR           bcs  age  cnt
# 0  SRR8426368-TAGCTGAATGAG  SRR8426368  TAGCTGAATGAG    3  0.0
# 1  SRR8426368-CATGGCAAGGTT  SRR8426368  CATGGCAAGGTT    3  0.0
# 2  SRR8426368-TGTCGCCGCAAA  SRR8426368  TGTCGCCGCAAA    3  0.0
# 3  SRR8426368-GCTACTATGGAT  SRR8426368  GCTACTATGGAT    3  0.0
# 4  SRR8426368-ATTAAAGCCATC  SRR8426368  ATTAAAGCCATC    3  0.0

# %%
# unique cnt
df['age'].unique()
# Out:
# array([ 3, 24])

# %%
ace2
# Out:
# View of AnnData object with n_obs × n_vars = 11887 × 1
#     obs: 'SRR_bcs', 'SRR', 'bcs', 'age'
#     var: 'gene'
#     uns: 'log1p'
#     layers: 'raw', 'norm', 'log1p', 'scale'

# %%
l_s = adata.X.sum(axis=1).reshape(-1).tolist()[0]
condition = pd.get_dummies(adata.obs["age"], prefix=None)
condition = condition[3].values

# %%
print(condition)
# Out:
# [1 1 1 ... 0 0 0]

# %%
print(l_s)
# Out:
# [6725.999998, 5043.999997999999, 5316.999993, 4532.999992, 4792.999999000001, 6230.999993, 6788.999997, 7129.999997999999, 5578.999997999999, 6277.999993, 4716.999999, 4896.000002999999, 3809.0000019999998, 3569.0000029999997, 5068.999999000001, 3668.999999, 3427.999997, 3320.000001, 3555.9999980000002, 3926.999998, 3843.999995, 3673.9999960000005, 4422.999997999999, 4047.000008, 2946.999997, 2974.9999980000002, 2739.999997, 3371.9999999999995, 2654.999999, 3017.999997, 2745.9999970000003, 3217.0, 2608.0, 2309.0, 3864.0, 2942.000011, 3430.999997, 3871.0, 3100.0, 2836.000003, 2313.000006, 2890.0000099999997, 3389.0, 2169.999997, 2934.000001, 3140.0, 2506.9999980000002, 2504.9999989999997, 2437.999997, 2844.999994, 3100.000006, 2561.999999, 2881.0, 2839.000008, 2455.9999989999997, 2746.999999, 2365.0, 1974.0000009999999, 2545.0, 2874.9999930000004, 2224.999995, 2167.9999989999997, 2140.9999930000004, 2464.999999, 2322.999994, 2647.9999980000002, 2369.9999989999997, 2229.9999959999996, 
# ...

# %%
plt.scatter(l_s, condition, alpha=0.1)

# %%
print("There are a total of {:,.0f} counts of ACE2 among {:,.0f} cells".format(nd(df.cnt).sum(), df.shape[0]))
# Out:
# There are a total of 148 counts of ACE2 among 11,887 cells

# %%
print("Total number of age 3  cells: {:,.0f}\t({:,.2f}%)".format(df.eval("age==3").sum(), df.eval("age==3").sum()/df.shape[0]*100))
print("Total number of age 24 cells: {:,.0f}\t({:,.2f}%)".format(df.eval("age==24").sum(), df.eval("age==24").sum()/df.shape[0]*100))
# Out:
# Total number of age 3  cells: 6,581	(55.36%)
# Total number of age 24 cells: 5,306	(44.64%)

# %%
total_cnt = df.cnt.sum()
print("Total ACE2 counts (percentage of total) in age 3  cells: {:,.0f}\t({:,.2f}%)".format(df.query("age == 3 ").cnt.sum(), df.query("age==3").cnt.sum()/total_cnt*100))
print("Total ACE2 counts (percentage of total) in age 24 cells: {:,.0f}\t({:,.2f}%)".format(df.query("age == 24 ").cnt.sum(), df.query("age==24").cnt.sum()/total_cnt*100))
# Out:
# Total ACE2 counts (percentage of total) in age 3  cells: 102	(68.92%)
# Total ACE2 counts (percentage of total) in age 24 cells: 46	(31.08%)

# %%
print("Number of ACE2+ age 3  cells (% of age 3  cells): {:,.0f}\t({:,.4f}%)".format(df.query("age==3").eval("cnt>0").sum(), df.query("age==3").eval("cnt>0").sum()/df.query("age==3").shape[0]*100))
print("Number of ACE2+ age 24 cells (% of age 24 cells): {:,.0f}\t({:,.4f}%)".format(df.query("age==24").eval("cnt>0").sum(), df.query("age==24").eval("cnt>0").sum()/df.query("age==24").shape[0]*100))
# Out:
# Number of ACE2+ age 3  cells (% of age 3  cells): 89	(1.3524%)
# Number of ACE2+ age 24 cells (% of age 24 cells): 39	(0.7350%)

# %%
def vars(a, axis=None):
    """ Variance of sparse matrix a
    var = mean(a**2) - mean(a)**2
    """
    a_squared = a.copy()
    a_squared.data **= 2
    return a_squared.mean(axis) - np.square(a.mean(axis))

# %%
fig, ax = plt.subplots(figsize=(5,5))

x = nd(adata.X.mean(axis=1))
y = nd(vars(adata.X, axis=1))

ax.scatter(x, y, alpha=0.1)
ax.set(xlabel="mean", ylabel='variance')


plt.show()

# %%
#adata = adata[nd((adata.X>0).sum(axis=1)>=500)]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 11887 × 19632
#     obs: 'SRR_bcs', 'SRR', 'bcs', 'age'
#     var: 'gene'
#     uns: 'log1p'
#     layers: 'raw', 'norm', 'log1p', 'scale'

# %%
def bplot(x, y, ax):
    medianprops = dict(linestyle='', linewidth=2.5, color='white')
    meanlineprops = dict(linestyle='--', linewidth=2.5, color='#D43F3A')
    parts = ax.boxplot(
        y, widths=0.5, showfliers=False, 
        medianprops=medianprops,
        meanprops=meanlineprops,
        showmeans=True,
        meanline=True)
    
    for i, j in zip(x,y):
        xx = np.random.normal(i, 0.1, size=len(j))
        ax.scatter(xx, j, color="k", s=100)

        #ax.scatter(i, j.mean(), color="#D43F3A")
      
    ax.set_xticks(x)
    return ax

# %% [markdown]
# # Count way

# %%
def anscombe(x):
  return 2*np.sqrt(x+3/8)

# %%
tmp = df.query("age==3").set_index("SRR")[["cnt"]]

#cnt = tmp.apply(np.log1p)
# tmp["cnt"] = cnt
tmp = tmp.query("cnt>0")
young = nd(tmp.groupby("SRR")[["cnt"]].mean().values)


## 
tmp = df.query("age==24").set_index("SRR")[["cnt"]]

#cnt = tmp.apply(np.log1p)
#tmp["cnt"] = cnt
tmp = tmp.query("cnt>0")
old = nd(tmp.groupby("SRR")[["cnt"]].mean().values)

# %%
fig, ax = plt.subplots(figsize=(7,7))

xlabels = ["3 month", "24 month"]
xidx = np.arange(len(xlabels))+1
y = [young, old]
t, p = stats.ttest_ind(y[0], y[1])

bplot(xidx, y, ax)

ax.set_xticklabels(xlabels, ha="center")
ax.set_ylabel("Average counts across cells")
ax.set_ylim((0, 2))

mean = mpatches.Patch(color="#D43F3A", label='Mean')
ax.legend(handles=[mean])

ax.annotate("p={:,.3f}".format(p), (1.5, ax.get_ylim()[1]*.02), ha="center")

plt.savefig("./counts.png",bbox_inches='tight', dpi=300)


plt.show()

# %% [markdown]
# # Fractional way

# %%
cells_per_sample = df.groupby("SRR")["cnt"].count()

# %%
tmp = df.query("age==3").query("cnt>0").groupby("SRR")[["cnt"]].count()
tmp["cells_per_sample"] = tmp.index.map(cells_per_sample).astype(int)
young = tmp.eval("cnt/cells_per_sample").values

tmp = df.query("age==24").query("cnt>0").groupby("SRR")[["cnt"]].count()
tmp["cells_per_sample"] = tmp.index.map(cells_per_sample).astype(int)
old = tmp.eval("cnt/cells_per_sample").values

# %%
df_data = df.query("cnt>0").groupby(["SRR", "age"])[["cnt"]].count().reset_index()

# %%
# change age to boolean, 1 = age 24, 0 = age 3
df_data["age"] = df_data["age"].replace({24:1, 3:0})
df_data['cells_per_sample'] = df_data["SRR"].map(cells_per_sample).astype(int)
df_data['cnt_per_cell'] = df_data.eval("cnt/cells_per_sample")
df_data
# Out:
#            SRR  age  cnt  cells_per_sample  cnt_per_cell
# 0   SRR8426358    1    2               398      0.005025
# 1   SRR8426359    1    7               397      0.017632
# 2   SRR8426360    0    3               695      0.004317
# 3   SRR8426361    0    9               295      0.030508
# 4   SRR8426362    1   12              1449      0.008282
# 5   SRR8426363    1    2               277      0.007220
# 6   SRR8426364    1    4              1034      0.003868
# 7   SRR8426365    0   13              1377      0.009441
# 8   SRR8426366    0   26              1245      0.020884
# 9   SRR8426367    0    9               724      0.012431
# 10  SRR8426368    0   14              1440      0.009722
# 11  SRR8426369    1    7               775      0.009032
# 12  SRR8426370    1    5               976      0.005123
# 13  SRR8426371    0    9               564      0.015957
# 14  SRR8426372    0    6               241      0.024896

# %%
# save df_data
df_data.to_csv("./size_condition_data.csv")

# %%
fig, ax = plt.subplots(figsize=(7,7))

xlabels = ["3 month", "24 month"]
xidx = np.arange(len(xlabels))+1
y = [young*100, old*100]
t, p = stats.ttest_ind(y[0], y[1])

bplot(xidx, y, ax)

ax.set_xticklabels(xlabels, ha="center")
ax.set_ylabel("Percentage of $ACE2+$ per replicate")
ax.set_ylim((0, 4))

mean = mpatches.Patch(color="#D43F3A", label='Mean')
ax.legend(handles=[mean])
ax.annotate("p={:,.3f}".format(p), (1.5, ax.get_ylim()[1]*0.02), ha="center")

plt.savefig("fractions.png",bbox_inches='tight', dpi=300)

plt.show()

# %%
young
# Out:
# array([0.00431655, 0.03050847, 0.00944081, 0.02088353, 0.01243094,
#        0.00972222, 0.01595745, 0.02489627])

# %% [markdown]
# # Simulation

# %%
n = 2000
m = 100
lam = np.linspace(0.001, 10, n)

# %%
fracgz = np.zeros_like(lam)
for lidx, l in enumerate(lam):
    x = np.random.poisson(l,m)
    fracgz[lidx] = (x>0).sum()/x.shape[0]

# %%
log1p = np.zeros_like(lam)
for lidx, l in enumerate(lam):
    log1p[lidx] = np.log1p(np.random.poisson(l,m)).mean()

# %%
naivelog1p = np.zeros_like(lam)
for lidx, l in enumerate(lam):
    naivelog1p[lidx] = np.log1p(lam[lidx])

# %%
funlog1p = np.zeros_like(lam)
for lidx, l in enumerate(lam):
    funlog1p[lidx] = np.log1p(lam[lidx]) - lam[lidx]/(2*(1+lam[lidx])*(1+lam[lidx]))

# %%
fig, ax = plt.subplots(figsize=(8,8))
fig.subplots_adjust(wspace=0)

red, blue = ("#D43F3A","#3182bd")
lwidth = 5
msize = 10
alpha=1

x = lam
y = funlog1p
ax.plot(x,y, linewidth=lwidth, label="Taylor Approx. of E[log1p($\lambda$)]", color=blue)
ax.legend(markerscale=7)
ax.set_ylabel("")
ax.set_xlabel("$\lambda$")



#############
x = lam
y = naivelog1p
ax.plot(x,y, linewidth = lwidth, label = "log1p($\lambda$)", color=red)
ax.plot(x[x>=1],np.log(x)[x>=1], label = "log($\lambda$)", linewidth=lwidth, color="black", linestyle="--")

ax.legend()

ax.set(**{
    "xscale": "log",
    "xlabel": "$\lambda$",
    "ylabel": "f($\lambda$)"
})

plt.savefig("taylor.png",bbox_inches='tight', dpi=300)

plt.show()

# %%
# !date
# Out:
# Tue Dec 22 01:33:00 UTC 2020
